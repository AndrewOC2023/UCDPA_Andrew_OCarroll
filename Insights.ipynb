# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
Continent = ['Africa', 'Asia', 'Oceania', 'Europe', 'North America', 'South America']
Cases = [12, 150, 8, 194, 100, 77]
sns.barplot(x= Continent, y= Cases)
# Out:
# <AxesSubplot: >

# %%
Continent = ['Africa', 'Asia', 'Oceania', 'Europe', 'N.America', 'S.America']
Deaths = [0.3, 1.4, .01, 1.8, 1.5, 1.3]
sns.barplot(x= Continent, y= Deaths)
# Out:
# <AxesSubplot: >

# %%
Continent = ['Africa', 'Asia', 'Oceania', 'Europe', 'North America', 'South America']
Death_Rate = [0.0182, 0.0306, 0.0262, 0.2446, 0.2455, 0.2964]
sns.barplot(y= Continent, x= Death_Rate)
# Out:
# <AxesSubplot: >

# %%
Country = ['USA', 'India', 'Brazil', 'France', 'Germany', 'UK', 'Russia', 'S.Korea', 'Italy', 'Turkey']
Cases = [84.2, 43.1,30.7, 29.2, 25.8, 22.2, 18.3, 17.8, 17.1,15.1]
sns.barplot(x= Country, y= Cases)
# Out:
# <AxesSubplot: >

# %%
Country = ['USA', 'India', 'Brazil', 'France', 'Germany', 'UK', 'Russia', 'S.Korea', 'Italy', 'Turkey']
Deaths = [1.0, .52,.67, .15, .14, .18, .38, .02, .17,.1]
sns.barplot(x= Country, y= Deaths)
# Out:
# <AxesSubplot: >

# %%
Country = ['USA', 'India', 'Brazil', 'France', 'Germany', 'UK', 'Russia', 'S.Korea', 'Italy', 'Turkey']
Death_Rate = [0.30, .04,.31, .22, .16, .26, .26, .05, .27,.12]
sns.barplot(y= Country, x= Death_Rate)
# Out:
# <AxesSubplot: >

# %%
Country = ['Latvia', 'Bahrain', 'Estonia', 'Cyprus', 'Trinidad', 'Swazil', 'Maurit', 'TimorL', 'Guinea', 'DjibouT']
Cases = [826, 577,574, 478, 155, 72, 38, 23, 16,15]
sns.barplot(x= Country, y= Cases)
# Out:
# <AxesSubplot: >

# %%
Country = ['Latvia', 'Bahrain', 'Estonia', 'Cyprus', 'Trinidad', 'Swazil', 'Maurit', 'TimorL', 'Guinea', 'DjibouT']
Deaths = [5.8, 1.5,2.6, 1.0, 3.9, 1.4, 0.9, 0.13, 0.18,0.19]
sns.barplot(x= Country, y= Deaths)
# Out:
# <AxesSubplot: >

# %%
Country = ['Latvia', 'Bahrain', 'Estonia', 'Cyprus', 'Trinidad', 'Swazil', 'Maurit', 'TimorL', 'Guinea', 'DjibouT']
Death_Rate = [0.314, 0.082,0.192, 0.084, 0.275, 0.119, 0.078, 0.010, 0.012,0.019]
sns.barplot(y= Country, x= Death_Rate)
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
import requests
data=pd.read_csv('coronavirus_summary.csv')
data.head()
# Out:
#        country continent  ...  total_tests_per_1m_population  population
# 0  Afghanistan      Asia  ...                        23455.0    40560636
# 1      Albania    Europe  ...                       632857.0     2871945
# 2      Algeria    Africa  ...                         5093.0    45325517
# 3      Andorra    Europe  ...                      3223924.0       77495
# 4       Angola    Africa  ...                        43136.0    34769277
#
# [5 rows x 12 columns]

# %%
sns.scatterplot(x='total_confirmed',y='total_deaths', data=data, hue='continent')
# Out:
# <AxesSubplot: xlabel='total_confirmed', ylabel='total_deaths'>

# %%
import pandas as pd
import requests
Vacc=pd.read_csv('Worldwide Vaccine Data.csv')
Vacc.head(10)
# Out:
#        Country  ...  % of population fully vaccinated
# 0  Afghanistan  ...                              28.0
# 1      Albania  ...                              44.0
# 2      Algeria  ...                              15.0
# 3       Angola  ...                              26.0
# 4    Argentina  ...                              84.0
# 5      Armenia  ...                              33.0
# 6        Aruba  ...                              79.0
# 7    Australia  ...                              85.0
# 8      Austria  ...                              77.0
# 9   Azerbaijan  ...                              49.0
#
# [10 rows x 5 columns]

# %%
Vacc_Top_10 = Vacc.sort_values(by = "Doses administered per 100 people", ascending=False).head(10)

# %%
Vacc_Top_10.head(10)
# Out:
#        Country  ...  % of population fully vaccinated
# 39        Cuba  ...                              88.0
# 33       Chile  ...                              93.0
# 82       Japan  ...                              82.0
# 23      Brunei  ...                              99.0
# 98       Macau  ...                              99.0
# 70   Hong Kong  ...                              91.0
# 182    Vietnam  ...                              89.0
# 105      Malta  ...                              94.0
# 27    Cambodia  ...                              89.0
# 162     Taiwan  ...                              87.0
#
# [10 rows x 5 columns]

# %%
Vacc_Top_10.plot.bar(x='Country', y='Doses administered per 100 people')
# Out:
# <AxesSubplot: xlabel='Country'>

# %%
Vacc.plot.bar(x='Country', y='Doses administered per 100 people')
# Out:
# <AxesSubplot: xlabel='Country'>

# %%
Vacc_Bottom_10 = Vacc.sort_values(by = "Doses administered per 100 people", ascending=True).head(10)

# %%
Vacc_Bottom_10.head(10)
# Out:
#                    Country  ...  % of population fully vaccinated
# 26                 Burundi  ...                               0.2
# 68                   Haiti  ...                               2.1
# 184                  Yemen  ...                               2.6
# 128       Papua New Guinea  ...                               3.5
# 99              Madagascar  ...                               7.3
# 135  Republic of the Congo  ...                              12.0
# 28                Cameroon  ...                              12.0
# 144                Senegal  ...                               8.3
# 36                   Congo  ...                               7.8
# 154            South Sudan  ...                              20.0
#
# [10 rows x 5 columns]

# %%
Vacc_Bottom_10.plot.bar(x='Country', y='Doses administered per 100 people')
# Out:
# <AxesSubplot: xlabel='Country'>

# %%
Fully_Vacc_Top_10 = Vacc.sort_values(by = "% of population fully vaccinated", ascending=False).head(10)

# %%
Fully_Vacc_Top_10.head(10)
# Out:
#             Country  ...  % of population fully vaccinated
# 98            Macau  ...                              99.0
# 173          U.A.E.  ...                              99.0
# 134           Qatar  ...                              99.0
# 23           Brunei  ...                              99.0
# 105           Malta  ...                              94.0
# 33            Chile  ...                              93.0
# 120       Nicaragua  ...                              91.0
# 70        Hong Kong  ...                              91.0
# 100  Mainland China  ...                              91.0
# 147       Singapore  ...                              90.0
#
# [10 rows x 5 columns]

# %%
Fully_Vacc_Top_10.plot.bar(x='Country', y='% of population fully vaccinated')
# Out:
# <AxesSubplot: xlabel='Country'>

# %%
Fully_Vacc_Bottom_10 = Vacc.sort_values(by = "% of population fully vaccinated", ascending=True).head(10)

# %%
Fully_Vacc_Bottom_10.head(10)
# Out:
#                    Country  ...  % of population fully vaccinated
# 26                 Burundi  ...                               0.2
# 68                   Haiti  ...                               2.1
# 184                  Yemen  ...                               2.6
# 128       Papua New Guinea  ...                               3.5
# 99              Madagascar  ...                               7.3
# 36                   Congo  ...                               7.8
# 144                Senegal  ...                               8.3
# 135  Republic of the Congo  ...                              12.0
# 57                   Gabon  ...                              12.0
# 28                Cameroon  ...                              12.0
#
# [10 rows x 5 columns]

# %%
Fully_Vacc_Bottom_10.plot.bar(x='Country', y='% of population fully vaccinated')
# Out:
# <AxesSubplot: xlabel='Country'>
